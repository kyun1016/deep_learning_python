# %%
import numpy as cpu_np
import cupy as np
import matplotlib.pyplot as plt

# -- 각 설정값 --
n_time = 20         # 시점의 수
n_mid = 128         # 은닉층 

eta = 0.01          # 학습률
clip_const = 0.02   # 노름의 최댓값을 구하는 상수
beta = 2            # 확률분포 폭(다음 시점에 올 문자를 예측할 때 사용)
epoch = 50
batch_size = 128

def sigmoid(x):
    return 1/(1+np.exp(-x))

def clip_grad(grads, max_norm):
    norm = np.sqrt(np.sum(grads*grads))
    r = max_norm / norm
    if r < 1:
        clipped_grads = grads*r
    else:
        clipped_grads = grads
    return clipped_grads

# -- 훈련용 텍스트 --
with open("human_problem.txt", mode="r", encoding="utf-8-sig") as f:
    text = f.read()
print("문자 수:", len(text))     # len()으로 문자열의 문자 수도 출력 가능

# -- 문자와 인덱스 연결 --
chars_list = sorted(list(set(text)))    # set으로 문자 중복 제거
n_chars = len(chars_list)
print("문자 수 (중복없음) :", n_chars)

char_to_index = {}     # 문자가 키이고 인덱스가 값인 딕셔너리
index_to_char = {}     # 인덱스가 키이고 문자가 값인 딕셔너리

for i, char in enumerate(chars_list):
    char_to_index[char] = i
    index_to_char[i] = char
    

# -- 시계열로 나열된 문자와 다음 차례 문자 --
seq_chars = []
next_chars = []
for i in range(0, len(text) - n_time):
    seq_chars.append(text[i:i+n_time])
    next_chars.append(text[i+n_time])
    
# -- 입력과 정답을 원핫 인코딩으로 표시 --
input_data = np.zeros((len(seq_chars), n_time, n_chars), dtype=np.bool)
correct_data = np.zeros((len(seq_chars), n_chars), dtype=np.bool)
for i, chars in enumerate(seq_chars):
    # 정답을 원핫 인코딩으로 표시
    correct_data[i, char_to_index[next_chars[i]]] = 1
    for j, char in enumerate(chars):
        # 입력을 원핫 인코딩으로 표시
        input_data[i, j, char_to_index[char]] = 1
        
# -- LSTM층 --
class LSTMLayer:
    def __init__(self, n_upper, n):
        # 각 파라미터의 초깃값
        self.w = np.random.randn(4, n_upper, n) / np.sqrt(n_upper)
        self.v = np.random.randn(4, n, n) / np.sqrt(n)
        self.b = np.zeros((4, n))
        
    # y_prev, c_prev: 이전 시점의 출력과 기억 셀
    def forward(self, x, y_prev, c_prev):
        u = np.matmul(x, self.w) + np.matmul(y_prev, self.v) + self.b.reshape(4,1,-1)
        
        a0 = sigmoid(u[0])    # 망각 게이트
        a1 = sigmoid(u[1])    # 입력 게이트
        a2 = np.tanh(u[2])    # 새로운 기억
        a3 = sigmoid(u[3])    # 출력 게이트
        
        self.gates = np.stack((a0,a1,a2,a3))
        
        self.c = a0*c_prev + a1*a2   # 기억 셀
        self.y = a3*np.tanh(self.c)  # 출력
        
    def backward(self,x,y,c,y_prev, c_prev, gates, grad_y, grad_c):
        a0,a1,a2,a3 = gates
        tanh_c = np.tanh(c)
        r = grad_c + (grad_y*a3)*(1-tanh_c**2)
        
        # 각 delta
        delta_a0 = r*c_prev*a0*(1-a0)
        delta_a1 = r*a2*a1*(1-a1)
        delta_a2 = r*a1*(1-a2**2)
        delta_a3 = grad_y*tanh_c*a3*(1-a3)
        
        deltas = np.stack((delta_a0, delta_a1, delta_a2, delta_a3))
        
        # 각 파라미터의 기울기
        self.grad_w += np.matmul(x.T, deltas)
        self.grad_v += np.matmul(y_prev.T, deltas)
        self.grad_b += np.sum(deltas, axis=1)
        
        # x 기울기
        grad_x = np.matmul(deltas, self.w.transpose(0,2,1))
        self.grad_x = np.sum(grad_x, axis=0)
        
        # y_prev 기울기
        grad_y_prev = np.matmul(deltas, self.v.transpose(0,2,1))
        self.grad_y_prev = np.sum(grad_y_prev, axis=0)
        
        # c_prev 기울기
        self.grad_c_prev = r*a0
        
    def reset_sum_grad(self):
        self.grad_w = np.zeros_like(self.w)
        self.grad_v = np.zeros_like(self.v)
        self.grad_b = np.zeros_like(self.b)
        
    def update(self, eta):
        self.w -= eta*self.grad_w
        self.v -= eta*self.grad_v
        self.b -= eta*self.grad_b
        
    def clip_grads(self, clip_const):
        self.grad_w = clip_grad(self.grad_w, clip_const*np.sqrt(self.grad_w.size))
        self.grad_v = clip_grad(self.grad_v, clip_const*np.sqrt(self.grad_v.size))
        
# -- 전결합 출력층 --
class OutputLayer:
    def __init__(self, n_upper, n):
        # 자비에르 초기화 기반의 초깃값
        self.w = np.random.randn(n_upper, n) / np.sqrt(n_upper)
        self.b = np.zeros(n)
        
    def forward(self, x):
        self.x = x
        u = np.dot(x, self.w) + self.b
        self.y = np.exp(u)/np.sum(np.exp(u), axis=1).reshape(-1,1)  # 소프트맥스 함수
        
    def backward(self, t):
        delta = self.y - t
        
        self.grad_w = np.dot(self.x.T, delta)
        self.grad_b = np.sum(delta, axis=0)
        self.grad_x = np.dot(delta, self.w.T)
        
    def update(self, eta):
        self.w -= eta * self.grad_w
        self.b -= eta * self.grad_b
        
# -- 각 층의 초기화 --
# 이때, input_layer와 output_layer의 개수는 문자열 분석을 통해 얻은 단어 수와 같다.
lstm_layer = LSTMLayer(n_chars, n_mid)
output_layer = OutputLayer(n_mid, n_chars)

# -- 훈련 --
def train(x_mb, t_mb):
    # 순전파 LSTM층
    y_rnn = np.zeros((len(x_mb), n_time+1, n_mid))
    c_rnn = np.zeros((len(x_mb), n_time+1, n_mid))
    gates_rnn = np.zeros((4, len(x_mb), n_time, n_mid))
    y_prev = y_rnn[:,0,:]
    c_prev = c_rnn[:,0,:]
    
    for i in range(n_time):
        x = x_mb[:,i,:]
        lstm_layer.forward(x, y_prev, c_prev)
        
        y = lstm_layer.y
        y_rnn[:,i+1,:] = y
        y_prev = y
        
        c = lstm_layer.c
        c_rnn[:,i+1,:] = c
        c_prev = c
        
        gates = lstm_layer.gates
        gates_rnn[:,:,i,:] = gates
        
    # 순전파 출력층
    output_layer.forward(y)
    
    # 역전파 출력층
    output_layer.backward(t_mb)
    grad_y = output_layer.grad_x
    grad_c = np.zeros_like(lstm_layer.c)
    
    # 역전파 LSTM층
    lstm_layer.reset_sum_grad()
    for i in reversed(range(n_time)):
        x = x_mb[:,i,:]
        y = y_rnn[:,i+1,:]
        c = c_rnn[:, i+1, :]
        y_prev = y_rnn[:,i,:]
        c_prev = c_rnn[:,i,:]
        gates = gates_rnn[:,:,i,:]
        
        lstm_layer.backward(x,y,c,y_prev, c_prev, gates, grad_y, grad_c)
        grad_y = lstm_layer.grad_y_prev
        grad_c = lstm_layer.grad_c_prev
        
    # 파라미터 갱신
    lstm_layer.clip_grads(clip_const)
    lstm_layer.update(eta)
    output_layer.update(eta)
    
# -- 예측 --
def predict(x_mb):
    # 순전파 LSTM층
    y_prev = np.zeros((len(x_mb), n_mid))
    c_prev = np.zeros((len(x_mb), n_mid))
    
    for i in range(n_time):
        x = x_mb[:,i,:]
        lstm_layer.forward(x,y_prev, c_prev)
        y = lstm_layer.y
        y_prev = y
        c = lstm_layer.c
        c_prev = c
        
    # 순전파 출력층
    output_layer.forward(y)
    return output_layer.y

# -- 오차 계산 --
def get_error(x, t):
    limit = 1000
    if len(x) > limit:    # 측정 샘플 수 최댓값 설정
        index_random = np.arange(len(x))
        np.random.shuffle(index_random)
        x = x[index_random[:limit], :]
        t = t[index_random[:limit], :]
    y = predict(x)
    # 교차 엔트로피 오차
    return -np.sum(t*np.log(y+1e-7))/batch_size

def create_text():
    prev_text = text[0:n_time]   # 입력
    created_text = prev_text     # 생성되는 텍스트
    print("Seed:", created_text)
    
    for i in range(200):    # 200자 문자 생성
        # 입력을 원핫 인코딩으로 표시
        x = np.zeros((1, n_time, n_chars))
        
        for j, char in enumerate(prev_text):
            x[0, j, char_to_index[char]] = 1
        
        # 다음 문자 예측
        y = predict(x)
        p = y[0] ** beta    # 확률분포 조정
        p = p / np.sum(p)   # p의 합을 1로
        next_index = np.random.choice(len(p), size=1, p=p)
        next_char = index_to_char[int(next_index[0])]
        created_text += next_char
        prev_text = prev_text[1:] + next_char
        
    print(created_text)
    print()  # 개행
    
error_record = []
n_batch = len(input_data) // batch_size    # 1에포크당 배치 개수
for i in range(epoch):
    # -- 학습 --
    index_random = np.arange(len(input_data))
    np.random.shuffle(index_random)     # 인덱스 임의 섞기
    for j in range(n_batch):
        # 미니 배치 구성
        mb_index = index_random[j*batch_size : (j+1)*batch_size]
        x_mb = input_data[mb_index, :]
        t_mb = correct_data[mb_index, :]
        train(x_mb, t_mb)
        
        # -- 경과 표시 --
        print("\rEpoch: " + str(i+1) + "/"+str(epoch)+ " " + str(j+1) + "/" +str(n_batch),end="")
        
    # -- 오차 계산 --
    error = get_error(input_data, correct_data)
    error_record.append(error)
    print(" Error: " +str(error))
    
    # -- 경과 표시 --
    create_text()
    
plt.plot(range(1, len(error_record)+1), error_record, label="error")
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.legend()
plt.show()
# Out:
# 문자 수: 60322
# 문자 수 (중복없음) : 980
# <ipython-input-3-99ef84d57d89>:53: DeprecationWarning: `cupy.bool` is a deprecated alias for the Python scalar type `bool`. Please use the builtin `bool` or its corresponding NumPy scalar type `cupy.bool_` instead.
#   input_data = np.zeros((len(seq_chars), n_time, n_chars), dtype=np.bool)
# <ipython-input-3-99ef84d57d89>:54: DeprecationWarning: `cupy.bool` is a deprecated alias for the Python scalar type `bool`. Please use the builtin `bool` or its corresponding NumPy scalar type `cupy.bool_` instead.
#   correct_data = np.zeros((len(seq_chars), n_chars), dtype=np.bool)
# Epoch: 1/50 471/471 Error: 31.333828020642414
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇 그다. 그내 어하며 그이 에 어 어 그는 그가 가 이는 말의 것를 가 어에 그 이 이 그다.
# 그 어다. 그리 하은 그다. 그머 소 어았 고 이 가 가 어다. 그하 이 해 물고 이 어 이 사을 하아 말이 같이 그는 선다. 그 에 때 것 을 있다. 그옥다. 그 하리 어은 새어는 비다.
# 그에 그다.
# 그다. 그가 그 그 고 아 어하는 이자 어고 나 하한 사 그는
#
# Epoch: 2/50 471/471 Error: 29.765119687067426
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇서 하는 양이는 아지 생에 저 놓에 보다. 선비는 그리고 지며 그는 내 어가 보고 그는 가 어에나 이는 있라다. 그는 무나은 그리는 소나 그리는 하고 내는 하니는 그러이 선리고 사어 돌이 들은 어자가 이 말을 생어나 가서 보어 가 이다.
# 이 어에 같니 한 어하고 보라다. 옥는 이 이 것어이 여 되을 그리는 집지지 내다.
# 그는 보리는 옥점을 가며 그는 어 하
#
# Epoch: 3/50 471/471 Error: 27.73251548469061
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇고 들라가 나리고 나고 들어니니를 이르고 그 어머니는 나서 그의 바각이 보았다. 그째는 양이를 다가 들어 내리고 있다. 그리고 일람이 보는 하고 다. 그래서 이 해 이 들이 말이 하고, 선비는 하고 내다. 이 있는 말이 가가 하고 말이 들어 어머니는 놓아 말이 어 아라가 이 내고 어나니다. 그는 그는 장라고 생고 하는 잠 어서 나 없이다. 그는 그의 어머니
#
# Epoch: 4/50 471/471 Error: 26.168340528415424
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 가게 같았다. 그리고 선비는 모에 바자 다. 그는 성이 얼가 큰 안에 나 다고 가는 이 들어가 못 가 말을 보았다.
# 그는 그래 이 고 주가 이는 것이다. 그리고 그는 바 이는 보았다. 그래 무 있는 듯이 따리 가는 것이 들어나 가서 계이는 돌어서 가 가 가 가에 나 이 꺼을 한 하는 주 주에는 것이다.
# 그는 말이 첫째는 가주 들어가 지는 것이다. 그리
#
# Epoch: 5/50 471/471 Error: 25.953432646152066
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 지며 죽을 하고 남이 빨었다. 그리고 어머니는 이렇게 그리고 하여 것이다. 그리고 그래서 어머니는 잠을 하였다. 그는 이 가의 이 말을 하고 이렇게 않고 하고 말이 후 나 이 지고 나서 이 소리가 이 있다. 그의 어서 가리를 하고 바라보았다. 그는 옥점의 어머니는 그의 웬 없는 이 들었다. 그리고 자리에 가 내어 일어나 가고 이 웃었다. 이나 않니는 이
#
# Epoch: 6/50 471/471 Error: 25.821302721246287
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 가와 이 아 가 자리를 하였다. 그리고 그래 선비를 어머니 말을 잘 자며 또 말이 동하는 그 사람이 그의 또 가 보았다. 그들은 선비 어머니 두 없이 타만 물을 방 못 없으로 그래서 내우 감이 무슨 소리를 바라보았다. 그러나 무슨 그 안 못 때 아무 얼굴을 가 주고 못하였다. 그러나 그 음을 어 생각하였다. 그리고 어디 아 있는 그 아 안 씻에 김시 둘
#
# Epoch: 7/50 471/471 Error: 23.62877812642043
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 지 일어오니, 신철이는 것을 보며,
# 아, 어머니는 호가 가지고 있다. 이서방은 눈이 보았다. 그리고 무슨 말을 나 들어 섭다가 그래서 이렇게 하였다. 그리고 무슨 해는 이가 가루나, 그 어머니는 듯하였다. 그리고 말이 가지 않았다. 그리고 선비를 이 보았다. 그리고 자리를 보았다. 그리고 아무까지, 그리고 아니다.
# 그리고 어디나 가지 이렇게 가지 않았다
#
# Epoch: 8/50 471/471 Error: 22.644214300216
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웃는 말을 보고 그런 이 어머니는 어머니는 그의 어머니는 이 보이 되어 나려고 나오는 것을 다시 그렇게 그의 이런 그리고 그리고 그는 손을 안에 내어 되어 오는 것을 한 일어 있다.
# 그는 어디 나무서 그의 어머니를 보고 나왔다.
# 이서방은 그는 어머니는 이 앞을 바라보았다. 그래서 어머니는 신철이를 들어 놓았다. 그래서 그리고 그러 소리를 보았다. 그는
#
# Epoch: 9/50 471/471 Error: 22.349850637877367
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하여 하여 듯이 물었다. 그는 어머니는 이 어떤 가는 듯한 것이 싶었다.
# 나서 이 얼굴이 방으로 들었다. 그리고 그의 얼굴을 하였다. 그리고 어머니는 어머니가 자라가 가슴을 하였다.
# 그는 머리를 자리 들었다. 그리고 머리를 하는 듯하여 있었다.
# 이제방 하여 소리가 하는 것이 그런 이렇게 하였다. 그리고 어진 가슴이 방 바라보았다. 그는 어머니는 이런 말
#
# Epoch: 10/50 471/471 Error: 23.18445369796475
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하는 것은 것이다.
# 옥점이는 옥점이는 이 있는 것 이 있는 것이 피기의 이 있다. 그의 어머니가 이 없어 있는 것이다. 그리고 무슨 일어나서 선비를 다시고 내어 가 있는 것을 내려가 선비를 내다. 그리고 아니 자기를 하고 나왔다. 그리고 선비를 바라보았다. 이렇게 생각하며 이렇게 누가 선비는 어머니를 임어 서 있다. 어서 어머니는 이 아이 말을 보니
#
# Epoch: 11/50 471/471 Error: 21.013580059936714
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말…….
# 나무서 어머니는 담기를 하고 못 지며 가슴이 나왔다. 그리고 나무다리를 힘며 보며, 그는 참잎 들었다.
# 아버지, 어떤 선비를 보며 이렇게 소리가 들어가 보고 나무 동시 어디서 선비는 어머니는 가 사람이 들었다. 그것 어서 선비가 두 있는 것 자지 않는 것을 보고 이렇게 하고 이 소리를 보았다. 그리고 첫째는 바라보았다. 그리고 밖으로 들어 보며
#
# Epoch: 12/50 471/471 Error: 21.626515046863325
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말았다.
# 이놈이, 그의 머리를 가지고 않았다.
# 그 먼리 나이 사람이 들어가 사람이 그의 어머니는 벌을 울고 돌아보았다. 그는 일어나 가지 않았다.
# 그는 어머니를 돌아보며 이렇게 말하였다. 그리고 무슨 선비를 불어진다.
# 선비는 그의 눈을 가리며 해서 선비가 그는 사람이 그의 눈을 가세고 나왔다.
# 그리고 나무 기를 가지고 않았다. 이서방은 그의 탁 방으
#
# Epoch: 13/50 471/471 Error: 21.72807303728228
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그리고 이 자기를 바라보며 이렇게 웬하고 있수는 것을 가슴이 불어 놓았다. 그리고 계집을 바라보며 그리고 나무다리를 이렇게 하였다.
# 그는 무엇을 한 천에 지고 싶어 보았다. 그리고 소리를 바라보았다. 그리고 이리 생각하였다. 그리고 조금 생각하는 것을 다시 그는 것을 보았다. 그리고 나 안에 물어 보다가 하였다. 선비 어머니는 이 밤 생각하
#
# Epoch: 14/50 471/471 Error: 21.1392863128186
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하였다. 그는 어머니는 이렇게 하고 나왔다. 그는 어머니, 자기가 하고 마니까?
# 하고 않았다.
# 그 어머니는 이 아니로 해나왔다.
# 그는 어머니의 하고 있는 것이다. 그리고 무슨 말을 하고 아니 그렇게 않았다. 그래서 그는 말이 생각하였다. 그는 어머니는 등을 보며 이서방을 돌아본다. 그래서 그는 말을 하고 나왔다. 그, 어머니는 눈을 지금 어린다. 그리
#
# Epoch: 15/50 471/471 Error: 21.16313426694403
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하니 말하고 싶어 버렸다. 그는 어디 없는 것이 있는 것을 보고 이야 아니 없이 같은 것이다. 그는 이런 말이 있었던 것이다.
# 그는 이 아래를 이 원소를 들고 있다.
# 선비는 어머니를 울고 자기가 새로 올라갔다.
# 그는 눈을 이 아니까 하여 물인가지 않는 것을 바라보았다. 그러나 그는 어머니의 손을 빨고 있다. 그는 모양인지 하는 것이 서 들었다. 그는
#
# Epoch: 16/50 471/471 Error: 19.165254487903884
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다. 그는 어디로 가슴이 생각하였다. 그리고 그는 눈을 선비를 돌아보았다.
# 그는 어머니를 하고 들어가는 듯하였다. 그는 변소리에 그의 어머니를 돌아보았다.
# 그래서 그는 어머니를 웃하고 물러앉았다.
# 그는 일어나 가슴이 부시시 일어났다.
# 그는 어머니의 손을 가지고 들어가 있었다.
# 그는 저리 어디서 그의 눈을 다시금 그리고 머리를 돌아보았다.
# 어떻게 생
#
# Epoch: 17/50 471/471 Error: 20.64910230364316
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그리고 일어나며 나무다리는 모양이다. 그래서 그만 알자.
# 이렇게 말하는 것이다.
# 첫째는 호호 하는 것을 다보았다. 그 자기가 하고 있는 생각이 들었다.
# 이놈은 아침 아버지지 않는다. 그는 그의 말을 귀고 들어 가서 있다는 것이다.
# 옥점이는 무엇을 생각하였다. 그는 어머니는 그의 목을 바라보며 이렇게 말하였다. 그는 그의 일인을 바라보며 눈을
#
# Epoch: 18/50 471/471 Error: 18.79921612138066
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다.
# 그리고 이렇게 중얼거렸다. 그러나 그는 무심히 일을 하였다. 그는 무슨 말을 바라보았다. 그때고 그는 얼른 일어나며 그것이 그의 장자를 내려 보았다.
# 그는 무엇을 생각하였다. 그리고 그는 어머니가 부엌 참이나 돌아보았다. 그는 이렇게 생각하였다. 그러나 그는 신철이는 바라보았다. 그래서 그는 순간을 생각하였다. 그때에 그는 어머니가 하는
#
# Epoch: 19/50 471/471 Error: 20.197233047905172
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하고 싶은 것이 있지 하였다. 그래서 그 와 사람이 어디서 물을 조르고 일어나며 저편을 생각하였다.
# 그러구 말을 어떻게 시고 싶었다.
# 이애 저 큰 가지고 싶은 것이 보니, 이렇게 말을 하는 것이 웃었다.
# 이애 저놈은 어머니가 자기 돈 일어 가지 않았다.
# 그래서 그 집에 집은 말을 하고 싶은 것은 것이 없이 터이 있지 않았다.
# 이애 말을 가지고 요시 어
#
# Epoch: 20/50 471/471 Error: 19.285524417888315
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하고 하면 한참이나 오늘이 있다.
# 그는 어디라 선비를 다시 생각이 하였다.
# 그러나 그는 이렇게 생각하였다.
# 그래서 그의 어머니가 자기를 바라보았다.
# 그러나 이 숨을 가리고 싶었다.
# 그는 어머니를 보았다.
# 그러나 이것을 보이 되었다.
# 이 원소라! 하고 한참이나 무슨 생각을 하다가 그러데 하여 닫드다 바라보았다.
# 그러운 일이 어디가 가지고 싶
#
# Epoch: 21/50 471/471 Error: 18.9038968455066
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 가지 않았던 것이다.
# 이놈들의 가슴에 오는 것을 보고 싶구 하러 한참이나 무슨 일을 들어가 가슴을 다시 번 들었다.
# 그는 무의 생각을 하며 그 물 어미가 수가 없어 서 있지 못하였다.
# 선비 어머니는 무슨 말을 하면서 선비 어머니는 물을 물러앉았다. 그리고 선비 어머니 곁에 가서 들어가 있을 것 같았다. 오늘은 어머니 볼을 떠져 보고 싶었다.
# 그
#
# Epoch: 22/50 471/471 Error: 19.17464789309418
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하고 말았다. 그때에서 그는 어머니의 말에 자기가 자기에 볼까?
# 너 가면 사람들 가우.
# 그는 무슨 일이나 가자 하고 생각하였다. 그는 무심히 버렸다. 그는 무심히 자기를 보고, 저런 뭐 하고 생각하였다. 그러나 그는 무슨 생각이 하고 그런 생각이 하고 말이 되나 되었다. 그는 무슨 생각을 하는 소리가 들여다보았다. 그리고 그만 아버운 것이나 그렇게 하
#
# Epoch: 23/50 471/471 Error: 19.108922945977945
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하여라보았다. 그리고 무엇을 흔들었다. 그리고 나무다리를 바라보며 이렇게 하였다. 그리고 한숨이 끝을 놓고 서울 같았다. 그들은 눈가로 없다가 우리집을 대었다. 그리고 저 사람들이 없었다. 그리고 어디서방을 하여 사라보았다. 그리고 무슨 생각이 들어가서 들어가지고 싶어 놓고 있었다. 그는 할멈은 새로 다리를 후에 선비 어머니는 아랫목을 다보며 무슨 자식
#
# Epoch: 24/50 471/471 Error: 19.12382059715113
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하면 물러앉았다.
# 이애 저 소리가 나무다리를 할까? 이 동네 울어서 들어와, 어디 이 없이 되었다.
# 이애 말 하는 것이 어서 들어 왔다.
# 이걸 말을 이 아니요.
# 아이 어머니가 아당 것이 있어.
# 옥점이는 얼굴이 뛰어나왔다. 그리고 선비 어머니 곁으로 들어온 것을 보았다.
# 어머니, 어머니, 저 어머니가 선비 어머니는 이 집에 떠오른다. 그리고 어디 들어 들
#
# Epoch: 25/50 471/471 Error: 18.254864201475193
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각할 때 이 동네 가슴이 수 있는 것을 보았다. 그리고 안 오늘 그 집에 오는 것 같은 것이다.
# 그래서 그만 어머니는 벌써 일어나 마주 물 위에 달려 놓고 차로 사나 놓았다. 그리고 자기가 아버지 안 있었다. 그리고 이 나무다리를 따라 하고 싶었다.
# 그리고 그의 머리를 숙이 치며 아무 이 없이 오우 그 사람 같이 아니 이 동네 서 방 문 씻으로 나온
#
# Epoch: 26/50 471/471 Error: 18.72891209191269
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 말았다. 그리고 할멈 아마 다 앉아 있다.
# 그는 이서방, 그 나무 것이 그의 아버운 것이 그의 생각하였다.
# 그는 그래 그는 이리로 한숨을 푹 쉬며 불안으로 들어왔다.
# 그는 무슨 일이 다 오는 것이 그의 곁으로 온다.
# 이서방은 벌떡 일어나니다.
# 이애 이른 말이 나 그의 어머니는 그의 얼굴을 푹 쉬며 그는 벌떡 일어나며 그는 그의 숲을 한 듯이 아니라
#
# Epoch: 27/50 471/471 Error: 17.814316656909455
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하였다. 그리고 그 자태가 그렇게 하여 하였다. 그리고 어디로 들어 놓으며 아무 마루에 나서 물 위에 확자가 그의 눈에 어떻게 가서 있어 놓고 있다. 그리고 나무 하여 물그릇을 들고 보이고 한 말에 놓고 자기 하였다. 그리고 어디로 들어가 놓고 싶었다.
# 그러나 그것은 아랫목에 서서 사다가 그들은 하고 그의 어머니가 아무지를 바라보며 밖으로 아니 아니
#
# Epoch: 28/50 471/471 Error: 17.374555887918092
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다.
# 어머니가 주저가 가진 선비를 보며 그의 얼굴이 빨개지며 어머니를 가라고 말하고 나서 막 선비를 보지 않는 것 같지 못하였던 것을 다시금 바라보며, 어머니가 손을 치르고 나서 선비를 돌아보며 선비의 손을 달려 놓고 싶었다. 그는 계집애의 눈을 둥그리며 딸의 생긋 웃었다.
# 그는 머리를 돌아보았다. 그는 눈물 가지 가지를 않는 것이다.
# 그는 그의
# Epoch: 29/50 471/471 Error: 17.013600012119987
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다.
# 그는 무슨 말을 다시 선비는 무슨 말을 다시 되는 듯하였다.
# 그러나 그는 어머니의 비가 없다. 그는 어머니는 머리를 숙이 열고 나무다리를 돌아보았다.
# 어서 이리 그리고 무심히 말을 다 나왔다.
# 난장보살은 유서방은 너 나오는 것을 보았다.
# 그는 어머니는 딸기 말을 하는 듯이 그리로 나간 그의 어머니는 이렇게 중얼거리며 옥점의 어머니는 참이 어린
#
# Epoch: 30/50 471/471 Error: 16.92514393377182
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 중얼거리며 그의 머리를에 내려 버리며 그는 머리에 선비가 들어왔다. 그는 그만 일어나 그는 머리를 따라 버렸다. 그리고 그는 얼굴이 빨개를 들었다.
# 이 뭐 가! 그게 무엇 생각이 들어 들어 그의 눈을 바라보며 그는 맘을 쳐다보며 옥점의 앞에머리를 숙이 열고 올라들을 하였다. 그는 눈을 열고 섰다.
# 그는 그의 머리에 선비는 이렇게 중얼거리며 선비의 아래
#
# Epoch: 31/50 471/471 Error: 15.73962537812459
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그때 그리고 자기를 보고 싶었다.
# 아부지도 안 안 들어 왔다.
# 그래 옥점이는 그의 말에 잠이 들으며 손을 생각하였다. 그리고 그 사람이 없이 불을 수 하고 말았다. 그만 보일이 안방에 무슨 말을 하는 것이다.
# 그것은 말이 저 집어오세요.
# 그래야 그것이 가지면 내 보고 부엌으로 들어왔다.
# 이애 말이 뭐라?
# 옥점이는 처음에서 무슨 걸음을 벗어
#
# Epoch: 32/50 471/471 Error: 16.809564524607367
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 드나 한 더 가슴이 부엌으로 아까 놓고 있다! 이 동네 한 사람이 원소를 보고 있으려니 오래 한마디에 가슴은 신발 소리가 그의 부러 있다.
# 이서방은 첫째가 가라고 싶어 있는 것이 좋아하였다. 그래서 이제한 말을 할까? 그는 어디로 가슴이 열어 보았다. 그때에 어머니는 머리를 번쩍 보며,
# 아무꾼애는 머리를 바라보며,
# 아니 이 벽에 가만히 자기를 가지
#
# Epoch: 33/50 471/471 Error: 16.74275614215781
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 가슴이 되어 보았다. 그리고 이렇게 중얼거리며 무슨 말이다. 그리고 생각하는 듯이 돌아보며 문다도 그리로 하고 보이 얼마나 바라보았다. 그리고 한숨이 들여다보았다. 그리고 그 자태나 한 것 같이 없이 되었다. 그리고 그의 발길이 건너기 되었으니 이서방은 마침내 그 집 주저앉았다. 그는 그리고 돌아보았다. 그리고 자기에 이렇게 생각하였다. 그는 이
#
# Epoch: 34/50 471/471 Error: 15.878045657996193
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 말하고 귀로 들어가 든다. 그리고 한숨이 나무다리는 생각이었다.
# 이애 웬일이는 이 양미야. 그리고 뭐라고 말해야 말을 매는 이서방은 첫째가 그 집에 나왔다.
# 이애 이거 가서 우뚝 우리 소리가 나가라가 하는 옥점이가 나오곤 하는 이 동네 하니 그의 이 동네로 이서방이 바라보세요.
# 선비는 머리를 돌아보며 머뭇하는 소리가 들렸다.
# 그는 웬일인지 이 동
#
# Epoch: 35/50 471/471 Error: 17.256284779450272
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 떠오른다. 그래서 호미간을 받아 들어갔다.
# 아이 어머니는 신철이를 보았다. 그리고 담배를 휘쩍 들어 놓고 있다누.
# 그리고 무슨 이야기를 하고 돌아본다.
# 아이 어머니 곁에서 이서방의 손을 바라보며 뒤로 어디어 놓고 싶었다.
# 아직도 아래요.
# 아이 어머니가 왔는가?
# 아까 그것은 이렇게 말하고야 하는 것이 없었다.
# 이서방은 이 여자를 들고 싶었다.
# 그는 이
#
# Epoch: 36/50 471/471 Error: 16.652997582162946
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하며 신철이가 가지고 싶었다. 그는 후로 어린애 저편을 물어 내려 주는 것이 좀 생각되었다.
# 그는 달걀을 들어 놓고 싶었다.
# 첫째는 어디가 아프다는 것을 깨고이 한숨을 푹 쉬었다. 오늘은 덕호는 안 들어가서 그는 이 원소를 벗어 놓으며 저편 이 새벽에 이서방은 불타보살이 조알 다 원짜.
# 이서방은 이 동네 가지가 게 된다. 신철이는 옥점이를 사랑하여
#
# Epoch: 37/50 471/471 Error: 16.713594775051998
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그리고 손에 이서방은 물 얻어 가지고 있는 것이 불쑥 들었다.
# 아부지 내일 이 새로 오는 것을 보았으나 하는 멍하니 이서방을 가워서 인정하는 원소를 돌아보며,
# 이놈 아래가 또 하게.
# 옥점이는 눈을 꾹 감았다. 그리고 나무를 다시금 생각하였다.
# 아직도 아버지가 이 앓을 두 어서 몹시 일어나서 그의 모양을 바라보았다.
# 어서 일어나 나 있는 것이
#
# Epoch: 38/50 471/471 Error: 16.236210057113666
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였던 것이다.
# 그제야 그들이 바라보았다. 그리고 호미간을 흔들며 그는 모양을 것이다. 그리고 부엌으로 들어왔다. 그리고 그들은 그 자태나무 하여 있는 것이 어디서 가지나 하여 이 들어서 그 푸른 사람이 오줌을 사나가 물러앉았다.
# 그들은 그 병은 사람이 없이 그릇을 훌어서 들어온 가슴이 겨우르며 나무다리를 바라보며 저편의 앞에 나왔다.
# 이 아니로 마
#
# Epoch: 39/50 471/471 Error: 16.125867843109535
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 눈을 감고 있지 않고 나온다. 그래서 선비가 자루 가서 소리나 가지고 있다.
# 그러나 선비의 음성은 흘금 바라보며 선비의 손을 쥐고 그의 이렇게 나왔다.
# 그래서 그는 안타까운 것을 보고 이렇게 떠오른다.
# 그는 어머니를 돌아보며 이렇게 오르며 물그릇을 가만히 보았다.
# 아는 것을 깨달고 나서 물을 후에 돌아앉았다.
# 아부지 말을 안 들어가서 방축을 좀 그래
#
# Epoch: 40/50 471/471 Error: 15.913724967409523
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웬일인지 하였다. 그래서 그는 어머니를 붙여다 있을 때 하고 생각하였다. 그는 참외를 붙들었다. 그는 눈을 꾹 감았다. 그는 참외를 따라 신철이를 끝은 사정어 있었다.
# 이서방은 어떤 줄을 깨어 지며, 어느냐지 있지도 못 사다 죽이 있다.
# 이 뭐 어디 있어요.
# 어서 어서 집어 오는 원소 하고 가슴이 붙어 주었다.
# 작은 일어 있어 있니?
# 이느 저 사람이 있
#
# Epoch: 41/50 471/471 Error: 15.134492932305951
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였던 것이다. 그래서 그는 이렇게 설망하였다. 그리고 이 동네로 올라온다. 그는 이 밤에 그의 이태나 주인 그의 손에 그의 이렇게 소리를 흘려 주인이 그의 손에 쥐어 놓고 그런 소리가 하였다. 그리고 그 이 여물 속에서 그 대를 보았으나 들여다는 그리고 이런 말하였다. 그는 이불을 보았다. 그리고 이리에 펄썩 주저앉았다. 그리고 그의 이편에 서울 이
#
# Epoch: 42/50 471/471 Error: 15.470470643814146
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하였다. 그리고 이렇게 말하여 이렇게 하였던 것이다.
# 이서방은 이 자리가 이리 지화를 보이었다.
# 어머니가 이 밤에 묻나가는 것을 깨달았다.
# 그리고 어디가 이 오늘이 싫다가 이 원소를 보고 이렇게 하였다.
# 이서방은 저 돈을 먹고 이렇게 중얼거렸다.
# 그리고 이리 이 아리 지화가 이렇게 중얼거리며 이서방의 손을 뽑고 나서 이렇게 떠오른다.
# 이 뭐 이 전에
#
# Epoch: 43/50 471/471 Error: 16.291472642836016
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다. 그리고 손을 가라고 돌아보니 저리 어디 해 좋지. 선비는 얼른 일 나 지를 않은 것이 불 끼 못 견다 갔는 것이 새로 한다 해를 보았으나 하는 생각이 들었다. 그리고 흐르는 이 원소를 바라보며 손끝 내려왔다.
# 이애 이 아리 없이 생각하였는 이 동네 한 명디를 보았으며 무슨 말에 말 해 같이 우리 싫었다.
# 그리고 이서방을 자기 그들 해라는 듯하
#
# Epoch: 44/50 471/471 Error: 15.229016696976117
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 웬일인지 얼굴이 생각히는 듯이 그의 생각까지 않는다. 그래서 그는 아랫목에 섰던 그는 가슴에 휙 시우두 하고 나무다리를 바라보고 나무다리를 이 또렷까지 내려는다. 그리고 그 나무꾼애는 그의 어머니의 생각을 하고 나무다리는 선비의 음성에 나무다리를 꽉 치고 있다가 그만 노려보았다.
# 아, 일어나마다 그 순간 그는 머리를 번쩍 들어 가며,
# 어디 있게 하고 생
#
# Epoch: 45/50 471/471 Error: 15.441870096156254
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 우리집에 서서 있었다. 그리고 한숨을 푹 쉬었다. 그리고 아프 기에게 그림자가 그림 보니 아무 하고 있기 위에 놓으며 그 곁으로 가서 큰 밭에를 보았다. 그리고 물끄러미 바라보았다. 그리고 무엇을 가진 뛰는 듯하였던 것이다. 그는 눈을 감고 쉬었다. 그리고 물끄러미 바라보았다. 그리고 이 동네가 떠오른다. 그리고 그 푸른 그러운 것이 그의 손발 길게 가
#
# Epoch: 46/50 471/471 Error: 14.54800524989782
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다. 그리고 문 밖에 빛나는 듯한 욕을 들이 가지고 싶은 것을 알자지 분하는 소리가 자리가 들어갔다. 그는 줄 아침에 그는 어머니의 손끝이 휙 돌아보았다. 그리고 손을 내밀어 보았다.
# 이애 이놈들! 이제 가지고 다 오셔요?
# 난장보살은 어떻게 아나왔다.
# 선비야 그들이 바싹 다가앉아 마주치 않으나 마주앉을 물었다.
# 이 자식 말이 다 오셨다.
# 그는 무의
#
# Epoch: 47/50 471/471 Error: 14.598874601489724
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하고 만나 보이지 않고 무슨 이야기를 하고 섰다. 그리고 자기를 따라 한 담배를 만나 보았다. 그리고 나무다리를 짚고 있지 않고 그의 어떤 곳에서 더러나는 이기를 가지고 들어온다.
# 아이, 그게 무슨 이야없이 울려 나가 없고 싶었다.
# 그는 그의 어머니는 선비를 보고 앉았다. 그리고 신발 소리가 그의 손을 놓고 있다. 그리고 무슨 말에 몇 번도 그의 어
#
# Epoch: 48/50 471/471 Error: 14.490074884097403
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였던 것 보지 않고 말로 막 떠오른 말이다. 그래 한 농민들은 목을 돌리며 이렇게 말하였던 것이다.
# 그래두 말 하고 우리집에 들어간다.
# 이거 가보아, 그게 하고 가지 밤에 그 지붕을…… 하고 생각하며 그 집 웃음하여 정말 하고 그의 돈 음성에 그의 주던 다 오래 사람들은 이 동네 농민들고 이렇게 말하고 그 웃음한 그 집 위로 왔다.
# 그 눈을 타고 이
#
# Epoch: 49/50 471/471 Error: 13.912554100926581
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말해야 하는 것이다. 그는 무심히 들어가며 그의 강한 몸이 가서 생각하였다. 그리고 그는 이렇게 중얼거리며 사라진다.
# 그리고 물끄러운 듯이 바라보며 선비의 곁으로 들어 온다. 그리고 다시 한번이나 해보았다.
# 그는 이 방에 나가서 서울 붙들었다.
# 그만 보일이나, 그 이놈들.
# 첫째는 얼른 그의 초가 사람한 물 선비가 또다시 한번이나 가지고 해서 그는 모양
#
# Epoch: 50/50 471/471 Error: 14.098561256558646
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다. 그리고 물끄러미 방 안아서 일어나며,
# 이애 가서 아무것도 같지 않고 싶었다. 그러나 그는 아무 아픔이 없었다.
# 그만 참으며 덕호를 하고 있나, 그래 마주 고 나 밖으로 나갔는가 하고 시원한 듯하였다.
# 그들은 그 속으로 나무꾼애는 저편으로 나왔다.
# 그만 중얼거리며 선비를 다시 섰다.
# 그래서 그는 어머니를 돌아보았다.
# 어서 들어가요.
# 옥점이는 얼
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-99ef84d57d89> in <module>
#     280     create_text()
#     281
# --> 282 plt.plot(range(1, len(error_record)+1), error_record, label="error")
#     283 plt.xlabel("Epochs")
#     284 plt.ylabel("Error")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     387         if len(tup) == 2:
#     388             x = _check_1d(tup[0])
# --> 389             y = _check_1d(tup[-1])
#     390         else:
#     391             x, y = index_of(tup[-1])
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1293     """Convert scalars to 1d arrays; pass-through arrays as is."""
#    1294     if not hasattr(x, 'shape') or len(x.shape) < 1:
# -> 1295         return np.atleast_1d(x)
#    1296     else:
#    1297         try:
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\shape_base.py in atleast_1d(*arys)
#      64     res = []
#      65     for ary in arys:
# ---> 66         ary = asanyarray(ary)
#      67         if ary.ndim == 0:
#      68             result = ary.reshape(1)
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asanyarray(a, dtype, order, like)
#     169         return _asanyarray_with_like(a, dtype=dtype, order=order, like=like)
#     170
# --> 171     return array(a, dtype, copy=False, order=order, subok=True)
#     172
#     173
#
# cupy\_core\core.pyx in cupy._core.core.ndarray.__array__()
#
# TypeError: Implicit conversion to a NumPy array is not allowed. Please use `.get()` to construct a NumPy array explicitly.
