# %%
import numpy as np
# import cupy as np
import matplotlib.pyplot as plt

# -- 각 설정값 --
n_time = 20         # 시점의 수
n_mid = 128         # 은닉층 

eta = 0.01          # 학습률
clip_const = 0.02   # 노름의 최댓값을 구하는 상수
beta = 2            # 확률분포 폭(다음 시점에 올 문자를 예측할 때 사용)
epoch = 50
batch_size = 128

def sigmoid(x):
    return 1/(1+np.exp(-x))

def clip_grad(grads, max_norm):
    norm = np.sqrt(np.sum(grads*grads))
    r = max_norm / norm
    if r < 1:
        clipped_grads = grads*r
    else:
        clipped_grads = grads
    return clipped_grads

# -- 훈련용 텍스트 --
with open("human_problem.txt", mode="r", encoding="utf-8-sig") as f:
    text = f.read()
print("문자 수:", len(text))     # len()으로 문자열의 문자 수도 출력 가능

# -- 문자와 인덱스 연결 --
chars_list = sorted(list(set(text)))    # set으로 문자 중복 제거
n_chars = len(chars_list)
print("문자 수 (중복없음) :", n_chars)

char_to_index = {}     # 문자가 키이고 인덱스가 값인 딕셔너리
index_to_char = {}     # 인덱스가 키이고 문자가 값인 딕셔너리

for i, char in enumerate(chars_list):
    char_to_index[char] = i
    index_to_char[i] = char
    

# -- 시계열로 나열된 문자와 다음 차례 문자 --
seq_chars = []
next_chars = []
for i in range(0, len(text) - n_time):
    seq_chars.append(text[i:i+n_time])
    next_chars.append(text[i+n_time])
    
# -- 입력과 정답을 원핫 인코딩으로 표시 --
input_data = np.zeros((len(seq_chars), n_time, n_chars), dtype=np.bool)
correct_data = np.zeros((len(seq_chars), n_chars), dtype=np.bool)
for i, chars in enumerate(seq_chars):
    # 정답을 원핫 인코딩으로 표시
    correct_data[i, char_to_index[next_chars[i]]] = 1
    for j, char in enumerate(chars):
        # 입력을 원핫 인코딩으로 표시
        input_data[i, j, char_to_index[char]] = 1
        
# -- LSTM층 --
class LSTMLayer:
    def __init__(self, n_upper, n):
        # 각 파라미터의 초깃값
        self.w = np.random.randn(4, n_upper, n) / np.sqrt(n_upper)
        self.v = np.random.randn(4, n, n) / np.sqrt(n)
        self.b = np.zeros((4, n))
        
    # y_prev, c_prev: 이전 시점의 출력과 기억 셀
    def forward(self, x, y_prev, c_prev):
        u = np.matmul(x, self.w) + np.matmul(y_prev, self.v) + self.b.reshape(4,1,-1)
        
        a0 = sigmoid(u[0])    # 망각 게이트
        a1 = sigmoid(u[1])    # 입력 게이트
        a2 = np.tanh(u[2])    # 새로운 기억
        a3 = sigmoid(u[3])    # 출력 게이트
        
        self.gates = np.stack((a0,a1,a2,a3))
        
        self.c = a0*c_prev + a1*a2   # 기억 셀
        self.y = a3*np.tanh(self.c)  # 출력
        
    def backward(self,x,y,c,y_prev, c_prev, gates, grad_y, grad_c):
        a0,a1,a2,a3 = gates
        tanh_c = np.tanh(c)
        r = grad_c + (grad_y*a3)*(1-tanh_c**2)
        
        # 각 delta
        delta_a0 = r*c_prev*a0*(1-a0)
        delta_a1 = r*a2*a1*(1-a1)
        delta_a2 = r*a1*(1-a2**2)
        delta_a3 = grad_y*tanh_c*a3*(1-a3)
        
        deltas = np.stack((delta_a0, delta_a1, delta_a2, delta_a3))
        
        # 각 파라미터의 기울기
        self.grad_w += np.matmul(x.T, deltas)
        self.grad_v += np.matmul(y_prev.T, deltas)
        self.grad_b += np.sum(deltas, axis=1)
        
        # x 기울기
        grad_x = np.matmul(deltas, self.w.transpose(0,2,1))
        self.grad_x = np.sum(grad_x, axis=0)
        
        # y_prev 기울기
        grad_y_prev = np.matmul(deltas, self.v.transpose(0,2,1))
        self.grad_y_prev = np.sum(grad_y_prev, axis=0)
        
        # c_prev 기울기
        self.grad_c_prev = r*a0
        
    def reset_sum_grad(self):
        self.grad_w = np.zeros_like(self.w)
        self.grad_v = np.zeros_like(self.v)
        self.grad_b = np.zeros_like(self.b)
        
    def update(self, eta):
        self.w -= eta*self.grad_w
        self.v -= eta*self.grad_v
        self.b -= eta*self.grad_b
        
    def clip_grads(self, clip_const):
        self.grad_w = clip_grad(self.grad_w, clip_const*np.sqrt(self.grad_w.size))
        self.grad_v = clip_grad(self.grad_v, clip_const*np.sqrt(self.grad_v.size))
        
# -- 전결합 출력층 --
class OutputLayer:
    def __init__(self, n_upper, n):
        # 자비에르 초기화 기반의 초깃값
        self.w = np.random.randn(n_upper, n) / np.sqrt(n_upper)
        self.b = np.zeros(n)
        
    def forward(self, x):
        self.x = x
        u = np.dot(x, self.w) + self.b
        self.y = np.exp(u)/np.sum(np.exp(u), axis=1).reshape(-1,1)  # 소프트맥스 함수
        
    def backward(self, t):
        delta = self.y - t
        
        self.grad_w = np.dot(self.x.T, delta)
        self.grad_b = np.sum(delta, axis=0)
        self.grad_x = np.dot(delta, self.w.T)
        
    def update(self, eta):
        self.w -= eta * self.grad_w
        self.b -= eta * self.grad_b
        
# -- 각 층의 초기화 --
lstm_layer = LSTMLayer(n_chars, n_mid)
output_layer = OutputLayer(n_mid, n_chars)

# -- 훈련 --
def train(x_mb, t_mb):
    # 순전파 LSTM층
    y_rnn = np.zeros((len(x_mb), n_time+1, n_mid))
    c_rnn = np.zeros((len(x_mb), n_time+1, n_mid))
    gates_rnn = np.zeros((4, len(x_mb), n_time, n_mid))
    y_prev = y_rnn[:,0,:]
    c_prev = c_rnn[:,0,:]
    
    for i in range(n_time):
        x = x_mb[:,i,:]
        lstm_layer.forward(x, y_prev, c_prev)
        
        y = lstm_layer.y
        y_rnn[:,i+1,:] = y
        y_prev = y
        
        c = lstm_layer.c
        c_rnn[:,i+1,:] = c
        c_prev = c
        
        gates = lstm_layer.gates
        gates_rnn[:,:,i,:] = gates
        
    # 순전파 출력층
    output_layer.forward(y)
    
    # 역전파 출력층
    output_layer.backward(t_mb)
    grad_y = output_layer.grad_x
    grad_c = np.zeros_like(lstm_layer.c)
    
    # 역전파 LSTM층
    lstm_layer.reset_sum_grad()
    for i in reversed(range(n_time)):
        x = x_mb[:,i,:]
        y = y_rnn[:,i+1,:]
        c = c_rnn[:, i+1, :]
        y_prev = y_rnn[:,i,:]
        c_prev = c_rnn[:,i,:]
        gates = gates_rnn[:,:,i,:]
        lstm_layer.backward(x,y,c,y_prev, c_prev, gates, grad_y, grad_c)
        grad_y = lstm_layer.grad_y_prev
        grad_c = lstm_layer.grad_c_prev
        
    # 파라미터 갱신
    lstm_layer.clip_grads(clip_const)
    lstm_layer.update(eta)
    output_layer.update(eta)
    
# -- 예측 --
def predict(x_mb):
    # 순전파 LSTM층
    y_prev = np.zeros((len(x_mb), n_mid))
    c_prev = np.zeros((len(x_mb), n_mid))
    
    for i in range(n_time):
        x = x_mb[:,i,:]
        lstm_layer.forward(x,y_prev, c_prev)
        y = lstm_layer.y
        y_prev = y
        c = lstm_layer.c
        c_prev = c
        
    # 순전파 출력층
    output_layer.forward(y)
    return output_layer.y

# -- 오차 계산 --
def get_error(x, t):
    limit = 1000
    if len(x) > limit:    # 측정 샘플 수 최댓값 설정
        index_random = np.arange(len(x))
        np.random.shuffle(index_random)
        x = x[index_random[:limit], :]
        t = t[index_random[:limit], :]
    y = predict(x)
    # 교차 엔트로피 오차
    return -np.sum(t*np.log(y+1e-7))/batch_size

def create_text():
    prev_text = text[0:n_time]   # 입력
    created_text = prev_text     # 생성되는 텍스트
    print("Seed:", created_text)
    
    for i in range(200):    # 200자 문자 생성
        # 입력을 원핫 인코딩으로 표시
        x = np.zeros((1, n_time, n_chars))
        
        for j, char in enumerate(prev_text):
            x[0, j, char_to_index[char]] = 1
        
        # 다음 문자 예측
        y = predict(x)
        p = y[0] ** beta    # 확률분포 조정
        p = p / np.sum(p)   # p의 합을 1로
        next_index = np.random.choice(len(p), size=1, p=p)
        next_char = index_to_char[int(next_index[0])]
        created_text += next_char
        prev_text = prev_text[1:] + next_char
        
    print(created_text)
    print( )  # 개행
    
error_record = []
n_batch = len(input_data) // batch_size    # 1에포크당 배치 개수
for i in range(epoch):
    # -- 학습 --
    index_random = np.arange(len(input_data))
    np.random.shuffle(index_random)     # 인덱스 임의 섞기
    for j in range(n_batch):
        # 미니 배치 구성
        mb_index = index_random[j*batch_size : (j+1)*batch_size]
        x_mb = input_data[mb_index, :]
        t_mb = correct_data[mb_index, :]
        train(x_mb, t_mb)
        
        # -- 경과 표시 --
        print("\rEpoch: " + str(i+1) + "/"+str(epoch)+ " " + str(j+1) + "/" +str(n_batch),end="")
        
    # -- 오차 계산 --
    error = get_error(input_data, correct_data)
    error_record.append(error)
    print(" Error: " +str(error))
    
    # -- 경과 표시 --
    create_text()
    
plt.plot(range(1, len(error_record)+1), error_record, label="error")
plt.xlabel("Epochs")
plt.ylabel("Error")
plt.legend()
plt.show()
# Out:
# 문자 수: 60322
# 문자 수 (중복없음) : 980
# <ipython-input-1-9dbbb5b58c34>:53: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   input_data = np.zeros((len(seq_chars), n_time, n_chars), dtype=np.bool)
# <ipython-input-1-9dbbb5b58c34>:54: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   correct_data = np.zeros((len(seq_chars), n_chars), dtype=np.bool)
# Epoch: 1/50 471/471 Error: 32.789993034574806
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇을 이내다.
# 그어는 어고는 무였는 그무다.
# 그이 이리는 이어의 그이가 여어에다.
# 그, 이았을 이는 이었다.
# 어며 그가 하을 이이점다.
# 그이 들은 그리다.
# 그하니다.
# 그는 그을 어리지다.
# 그에 그며,
# 방을 들나는 듯조 그비 어보은 아리이 그여에 그을 그는 한, 하들고 그을 그지 나을 옥간지다.
# 그게 이다.
# 이이 그머 머서 그지리는 랑어을 말이았다.
#
# 이이 치
#
# Epoch: 2/50 471/471 Error: 30.20616393197309
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇다. 그리 놓리로 생라시 것이 이 어리가 그 떤 어 앉도 말수 그는 그간 어 것어 한 이 있이 말하는 이 바을 내았다. 그리는 그어 이 이 하가 습이 무만 하는 이 이 다, 이 어우 생어 가 다. 그리는 찮 그리 어 쓸 아 일 그리 바 이 새을 가 어 싶어 이 보에 없는 솜 이 바을 부알 그여 자이 어머로 오 그리 가 없을 사에 이 이 바인 그는 이 이 하
#
# Epoch: 3/50 471/471 Error: 27.22057743615891
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 물하고 참 지 두 들어 하였다. 그리고 가 부아 것이나 수 거는 벌서 있다. 그리고 그 가 저라 하고 부소의 하였다. 그리고 그는 것을 것이 지 생이 한 못을 물이 손이를 말을 할 것이 들이 아시 가 들어보다. 그는 그리고 두을 주들이 들어 보았다.
# 그는 자에 그리가 들을 부기를 아 일어 뻗 가 있은 옥점이러 일이 하는 것을 하는 누각이 이 알을 것을
#
# Epoch: 4/50 471/471 Error: 24.888842394119173
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 뛰하였다. 그는 안 듯하였다. 그리고 기때 그리 안 보았다. 그리고 이 들어 일어 가지 여으로 이 다가 어 그는 것이 그들 소리를 지며 불을 다가 이려 개 들어 있다. 그리고 바라보았다. 그리고 이 길의 그리고 누았다. 옥점이는 너 이 하였다. 그리고 이 한 계아 사고 들어 하는 별은 그리고 사늘 그 들이 나고 그리고 전리를 가 일이 오는 중다. 그리고
#
# Epoch: 5/50 471/471 Error: 26.229188623772398
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하여를 벌으로 들어오았다. 그리고 이 자가 때 가지 가는 그 나고 정은 돌이라보았다.
# 그리고 손에 저집에 모어 가는 것을 번지를 보고 아니는 선비를 보려나 다시 자리들으로 나서 그는 것을 바라보았다. 그리고 손에 소리를 들었다.
# 민수는 그의 방에 또 섰다. 그리고 날에 상에서 어머니를 나서 가는 것이 가지 없다는 것을 있다.
# 옥점이가 선비를 보며 이 나
#
# Epoch: 6/50 471/471 Error: 25.93571161392723
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 소리고 들어 속 눈이 덕호는 얼 소리에 나서 그의 말을 가지고 들어 불자 가는 옥점의 어머니 어머니는 그의 그의 물의 이 가지 들어 나는 것이 것 아까지 그들은 그런 어머니는 말을 하는 것을 보았다. 그는 그런 이 물어 보았다. 그는 이 자가 수는 이렇게 하는 것이다. 그리고 그는 어머니는 선비 이 그래 어머니는 것을 들어 않았다. 그는 어머니는 집 이
#
# Epoch: 7/50 471/471 Error: 23.6065234428897
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 가하였다. 그러나 그는 없은 따라보며 그 끝을 가러 하고 그는 것을 가다. 그러나 하고 그는 것을 하며 어떤 알으로 그것을 어서 가서 가는 것을 하여 가서 가지 않고 때으로 바라보았다. 그러나 그는 어머니 가 가지도 어머니는 것을 하고 못하였다. 그는 손을 일어나며 하였다. 그러나 어머니가 하고 가지 않았다. 그 어머니는 코 물을 나 가지고 가지 않고
#
# Epoch: 8/50 471/471 Error: 24.469641471529133
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그리고 어머니가 들었다. 그리고 그의 이 사람이 사러나 들어 하고 말이 무각이 아왔다. 그리고 이 안 가려고 못 못 것이 그 받졌다. 그리고 생각하여 하고 어머니를 생각하며 한 것이 그 한 물를 섰다. 그 자리 돌아보았다. 그 자리가 당기 못 같았다. 그래서 이 생각을 왔다. 그들은 사람이 가리고 그것을 빙 열었다. 그리고 그 소리가 무런
#
# Epoch: 9/50 471/471 Error: 23.768012852481263
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 일어나지 않고 나무다.
# 그것은 이 안에 어디서 혹으며 이 어머니는 것이다.
# 어머니는 얼굴이 들어 오았다. 그리고 어머니는 것을 보며 이 안은 그 지 어머니는 이 일어나 것이다. 그리고 나온다.
# 그때, 어머니를 하고 오려 어디 있었다. 그리고 어머니가 바람하던 것이다. 그리고 나무다.
# 그 같은 어디 밤을 지 않았다. 그는 어머니는 그의 이 이 가 어떤
#
# Epoch: 10/50 471/471 Error: 23.3074254258016
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다.
# 이렇게 하여 자리를 사람하였다.
# 덕호는 머니에 그의 어머니는 소리를 바라보며 어머니는 것 다.
# 그 어머니는 말 앞에 그 저 사람의 어머니는 말 가야.
# 그들은 그의 계집애를 바라보며 그의 어머니는 곧 내가 기가 어린다.
# 그리고 그리고 무슨 말 매리며 그리 밖에 그의 손을 그래서 그의 어머니는 숨을 하고 보았다. 그리고 하여 사람까지 않았다.
#
#
# Epoch: 11/50 471/471 Error: 23.36132581785233
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 푹 말을 때는 것을 뜨고 싶어 놓았다.
# 이서방은 호호 자기를 들어 고게 것을 보았다. 그는 소리를 가서 울 자리가 일어나서 들어가는 것을 하고 뭐라는 것을 보았다. 그리고 나무 가슴이 나왔다.
# 그들은 아보니 머리를 가서 싶어 보아니?
# 옥점이는 머리를 돌아가지려오는 것을 하고 가슴을 하였다. 그리고 또다. 그리고 어머니는 것을 바라보며 옥점이가 나왔다.
#
# Epoch: 12/50 471/471 Error: 22.080216709142075
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 돌아보며,
# 그의 말을 바라보며,
# 이렇게 생각하며,
# 아버지, 그리고 이렇게 들어오며,
# 아버지.
# 그 사람은 그만 자를 들어왔다. 그리고 그의 아프어 왔다. 그리고 그리로 웃으며 그의 눈을 쓰어 왔으며 무슨 번이 바라보았다.
# 이서방은 그만 일어나는 것을 한 것이 그 나오는 것을 하고 돌아보며 그렇게 말아니며,
# 그는 그리고 무슨 말을 하며 혹은 불양이라.
# 그는
#
# Epoch: 13/50 471/471 Error: 22.06750415364506
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말을 하고 어머니의 그는 어머니가 이런 벌써 일어나는 것을 하는 소리가 집으로 들어 부지고 그는 어머니의 사람이 들어가는 것이다.
# 그는 아주 그들은 이 보겠다.
# 그는 어머니는 그들은 그는 무엇을 바라보았다.
# 그는 그는 소리에 그는 어머니는 선비를 보았다.
# 그는 소리에 어머니가 있다.
# 그리고 그만한 그리고 그는 소리가 그리고 나온다. 그리고 어머니는 눈이
#
# Epoch: 14/50 471/471 Error: 22.51861741315108
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 일어나서 이렇게 이것을 이러한 모양을 생각하였다.
# 그들은 선비와 어머니는 선비를 보았다.
# 아, 그는 이 동집에 그의 눈을 빨아 보니 이 어머니는 이 속에서 이 없이 나무다리를 이런 아래서 그의 이렇게 오늘을 보고 사람들이 집어나는 선비를 아버지 않았다.
# 선비는 이 있는 이 빨아 일이 들어가 이런 돌아보며 이 아들의 이 집에와서 그의 무심히 해라보았다.
#
#
# Epoch: 15/50 471/471 Error: 22.116171033977317
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇지 않았다.
# 그리고 어떻게 하늘 생각이 나무다리 못 밖으로 나온다.
# 아니 또다시 오시 문에서 이편으로 울고 빨아 있었다.
# 이서방은 그런 말을 들어가 하는 모양이다.
# 그는 이런 일어나서 나무다.
# 옥점이는 이서방은 그 머니가 이 나오는 것을 지고 싶은 것이다.
# 그 집에 가서 어디 가서 기 가지나 않으면 그 참이나 나무다. 그리고 나무다리를 가지며 신철이는 듯이
#
# Epoch: 16/50 471/471 Error: 20.555372197901644
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 한 말을 이렇게 말이 그만 어머니를 부르르 하여 보이는 소리를 들어…… 하는 모양이다.
# 아직 뭐는 것을 보고 싶으로 어디서 말을 하였다. 그는 자기에 손을 때 그의 어떤 가슴이 어머니는 바라보았다. 그리고 선비는 머리를 받아 들어다니,
# 이애 안에서 이렇게 말하였다. 그는 눈을 이렇게 웃었다. 그리고 어머니를 바라보며 이렇게 말을 때야, 아버지 않은 것을
#
# Epoch: 17/50 471/471 Error: 21.362445643563145
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 아랫하게라. 그의 눈을 이 창 나왔다. 그의 아랫도 들어간다.
# 덕호는 얼굴이 물을 하였다. 그리고 나무는 눈을 알았다.
# 이렇게 얼굴을 생각하려 하였다.
# 이서방은 또 동시로 들어가는 것을 하였다.
# 그러나 아버지 않은 것을 생각하고 있다가 때, 그는 눈이를 짚르며 그의 어디 가지고 있는 것을 하였다. 그러나 그의 위에 손을 들었다.
# 아버지 않는 것 같은 것
#
# Epoch: 18/50 471/471 Error: 22.442207487095008
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 물러 들어오는 듯이 찌미를 아니 들었다.
# 그래서 그는 말을 바라보았다. 그러나 말을 하니 어떻게 말을 견꼈다. 그리고 무슨 말을 하여 들어 번 들어 어째 말았다. 그리고 그리고 물어 들어갔다. 그리고 말을 하고 있다. 옥점이는 선비를 보며 나무서 조시시시 오르고 들어 놓고 물을 가리고 싶어 놓고 있는 것을 보았다. 그리고 싶어 버렸다. 선비는 머리를
#
# Epoch: 19/50 471/471 Error: 20.67098282707078
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말을 때 그리고 혼자 참이나 그는 어머니, 그래 말을 자기 이 있으나 할 것이 그 어머니는 선비를 아버지 않으면 그는 이렇게 말이 그들은 말이 그들은 저 원소를 바라보며,
# 선비는 머리를 따라 그들은 이 동네 그 집을 하고 돌아보며 이 자리를 가서 그는 소리가 아니 그들은 옥점이가 그 그의 어머니는 말이 그들은 옥점이는 그는 얼굴이 그의 어머니는 선비의
#
# Epoch: 20/50 471/471 Error: 21.50877957586406
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 바라보던 그는 부시시 일어났다.
# 선비 어머니는 서방 문을 가지고 싶은 듯하였다.
# 이서방은 그는 소리가 돌아 보았다. 그는 이리에 말을 뿐이고, 이 한 말을 생각하였다.
# 그는 무엇이 생각하였다.
# 그들은 저 집에서 일어나는 듯하여 보이는 것을 보았다.
# 그는 무슨 생각을 하고 싶은 한숨이 울어 들어오는 할멈은 곧 일어나며 이 집에 일어나는 그럼 생각하고 이렇
#
# Epoch: 21/50 471/471 Error: 21.226229345796334
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말을 한다.
# 그러지 어디가 그것 저 아래요.
# 그게 말을 내다가요?
# 그는 이렇게 떠오른다.
# 그가 지금 날에 이 원소를 가지고 방문이 그들은 말이 원소로 가지고 못하고 그의 어머니가.
# 그런 어떤 모양이가 그리고 올라가?
# 그들이 원소로 가 자기가 지요.
# 그러자 그가 어디 그래요.
# 그놈이 새에 자기가 없었다.
# 그러나 그까요?
# 그러 참이나 그것이 그러지 않은 것
#
# Epoch: 22/50 471/471 Error: 22.643058599176417
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 가 원게 모양 지붕 한 것 같지 않았다. 그 자 위에 어떤 것 같았다.
# 그 집 오지 않으나 신철의 곁으며 선비 어머니 머리를 바라보았다. 그 자리 무슨 듯이 먹고 그 문 선비 어머니는 그 달려 어서 실 아프다. 그 밤 속을 바라보며 이 있으며 그 사람 것을 바라보았다.
# 그러나 그 밤 해 가 자기 무의 어린 것 같았다. 그리고 섰다. 신철이는 그 자리
#
# Epoch: 23/50 471/471 Error: 20.263010448482333
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 소리는 신철이는 그의 아무 옥점이는 덕호는 그 사람들이 들어가 그리며 머리를 만 보이 아버지 않았다.
# 그리고 나 다시 올려보며 아무 생각하며 덕호는 벌써 이렇게 떠오른다. 그리고 그는 어머니,
# 아 그 자가 그리고 놀라 더 보았다.
# 그는 그의 말이 그의 어머니는 그 집을 때 그의 머리를 들고 그의 아무 모양이 없어 버렸다.
# 그리고 바라보았다.
# 그리고
#
# Epoch: 24/50 471/471 Error: 21.82937174760571
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 쓸어 보고 눈을 하고 번 간난 양복 생각지 고꼈다. 그리고 울려 입에 내며 이렇게 열리 돌아보며 것이 번 선비를 보고 부러졌다.
# 아무 무엇을 생각하지 않으며 선비를 웃고 잡아 보며 선비를 근 하고 지금 꺼라 보고 하고 지금 번 매었다.
# 그리고 오늘 말하였다. 그리고 이리로 번쩍 보고 내려 잡아 보며 부엌에서 가슴이 얼굴을 가고 부엌으로 번결에 보니 않고
#
# Epoch: 25/50 471/471 Error: 22.073703203675365
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 물러미 보았다. 그리고 무엇을 생각하며,
# 그들은 그의 손을 열고 있다. 그리고 가만히 그들은 그의 그리고 들었다. 그리고 그의 머리를 들었다. 그리고 어머니를 보았다. 그리고 지금 아랫도 그는 그의 손을 보았다. 그리고 보았다. 그리고 들리고 나가 있다.
# 이서 들어 보이 집을 보았다. 그리고 머리를 그러나 그때 그들은 그의 눈을 만바라보다가 그의 그리고
#
# Epoch: 26/50 471/471 Error: 21.420696788911545
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말았다. 그리고 아주 이 아버지 않았다. 그리고 나무다리 우시 일을 가서 더니 아버지 않았다. 그리고 아침에 그리고 그런 후 가지, 그는 머리를 바라보며 그리고 아버지 하였다. 그리고 아무 것이 아니며, 그리고 나오른다. 그래서 아니는 아무어진 것이 다시 아까지 않았다. 그래서 하는 소리를 하고 나무다리 이 아버지 않았다. 그리고 어떤 아무 아버지, 아
#
# Epoch: 27/50 471/471 Error: 22.252039398235873
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다.
# 그러나 게서방을 바라보았다.
# 어머니 신철이가 돌아보았다.
# 선비는 민수는 나는 옥점이 그 방 안방 다 걸어 지금 어서 그는 눈을 따라도 그의 머리에 섰다.
# 그래 조금 일시시 없는 것이 나무꾼히 나무 것을 보고 나무 것이 생각이 새울이구나도 나무꾼애는 옥점이는 불길할 나도 어머니까 그는 것을 바라보았다.
# 그것은 신철이가 나무꾼을 생각하였다. 그
#
# Epoch: 28/50 471/471 Error: 22.34266036565319
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 생각하였다. 그리고 어디로 가 없었다. 그리고 무엇을 들여다보았다.
# 어떻게 이 방.
# 글쎄 그 기어진 수 없이 휙 가지고 말하였다.
# 듣그리고 말을 다시금 하고 있으려 하고 해서 하고 요간난이 부엌으로 들어가서 옥점이는 그는 어머니의 간난이 기어진 사람이 없는 그의 아부터 없어 고게 들었다.
# 이거니는 얼굴이 부르르르 하고 마루로 집 자기 들어오니 그의 어머
# Epoch: 29/50 471/471 Error: 21.59221331724052
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 말하였다.
# 말하고 말으며 앉으며 그들이 내다.
# 신철이는 그러나는 신철이는 그러던 할하였다.
# 그때 그의 어머니는 것을 보았다.
# 선비는 얼굴을 먹고 하여 이 아니라고 하던 말이다.
# 그 치는 자성이 없다.
# 그리고 말을 열었다.
# 옥점이는 여러하였다.
# 말에 잠이 되었다.
# 이서 아무 먹고 있다.
# 이서방은 문을 짚고 하다. 그리고 앉으며 그의 어머니는 아니라고
#
# Epoch: 30/50 471/471 Error: 24.46360848445862
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 그의 그리고 나서서 이름을 하니야.
# 선비가, 그는 어머니의 한숨을 보았나가서 그의 어머니 어나보았다.
# 그리고 어머니의 이렇게 그리고 아니의 이리가 아서서 그의 나오는 어디서 어머니의 이렇게 그의 이렇게 그는 이렇게 어떤 어머니의 어머니의 그리고 어떻게 어떤
# 그리고 나서 어서 어떤 어나서 어머니의 자보이 어서서 어머니의 한한 혼었다.
# 그리고 어서 어디서
#
# Epoch: 31/50 471/471 Error: 24.28825061100704
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 오지 못하였다. 그래 한 소리가 하여 떠오시 하여 나오고 안에 한 불을 한다.
# 그는 무슨 얼핏 대로 놓고 물음을 하여 오지 못하였다. 소리를 하였다.
# 그들은 선비의 어머니.
# 그는 냉이 신철을 느만 생각을 보고 빽을 만나 떠오른 말을 하늘 집을 열고 가지고 하였다.
# 그러나 그의 무슨 말에 하고 하여 한다.
# 그만 그의 그래 보아 오지 않으면 아랫집을 후
#
# Epoch: 32/50 471/471 Error: 22.23567794002382
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 가슴은 이런 일어났다.
# 그는 소리가 입에 그리고 그의 어머니는 그는 듯하였던 것이 들어가?
# 정정 그는 것을 보며 어머니는 그의 어머니는 그런 것이다. 그는 그는 소리를 가 그는 가 있다. 그리고 나무다. 그리고 나무꾼 이 없어 버럭 그 가 없었다.
# 그는 소리가 가지고 그의 눈을 바라보며 그러 그는 것을 보며 그의 어머니는 그 푸로 가지 않았다. 그는
#
# Epoch: 33/50 471/471 Error: 22.85026150318571
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 후에 그리고 그의 그러나 그런 손이 그러 들은 선비 어머니 약을 까지며 아직에 생각을 때 그리고 아버지 않았다. 그리고 그리고 그리고 하였다. 그래 그의 생각하였다. 그리고 그리고 잠에 그리고 그의 이렇게 부지며 옥점이었다.
# 그리고 안으로 생각하였다. 그리고 나무꾼 생각하였다. 그리고 선비 이러한 생각하였다. 그리고 그들은 생각을 꾹 다시금 또 하는 것
#
# Epoch: 34/50 471/471 Error: 24.154689065272038
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 한참이 이서방으로 왔다. 그러나 이서방으로 왔었다.
# 이서방은 이렇게 생각하였다.
# 그러나 옥점이는 이렇게 생각하였다.
# 주인지?
# 하고 이서방으로 나왔다.
# 그러나 이렇게 하였다.
# 그래 이서방으로 부러 들어다.
# 그러나 옥점이는 …… 것이 것이 것을 사 것이 것을 끌었다.
# 이놈방 조보이 버렸다.
# 그러서 이서방으로 나왔다.
# 그래서 이렇게 이 있었다.
#
# Epoch: 35/50 471/471 Error: 22.942269433586148
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 물을 자고 이 눈을 자고 무엇을 다리는 이렇게 가지고 자기 이 누가지 않은 것이다. 그리고 아니 일어나며, 저 이 못이 들어오며 물이 후에 달았다.
# 그리고 물을 보고 하였다.
# 그러나!
# 그는 이렇게 물이 아리며 물이 한 일이 자기 못하였다. 그리고 이렇게 보고 무슨 자기 소리며 부엌에서 자기 보았다.
# 아무 소리친다.
# 그는 소리를 보고 이렇게 하고 바
#
# Epoch: 36/50 471/471 Error: 43.199520106599586
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇    나  말  ,
#   보   어 나   ,  점      그   보 하       그  고    하   어 바    보  그  그    간  보      ,  보  어  여  인    그  보  그 야   ,    그   리 어
#      않  그  그  물 ,  부    어     보
#    , 한   보   그 어   ,   면
#
# Epoch: 37/50 471/471 Error: 32.90931073264154
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇며 그의 하는 그는 그의 저점의 이…는 하는 그….
# 그리는 문으하는 그의 그는 그는 그의 하는 말을 같?
# 이는 보었을 말았을 선비는 그리. 그는 하고 말.
# 그는 참을 눈를 들이 그? 들이 덕을 가 그의 그러며 그리. 그……하이 가며 하도 그는 그는 그의 그리는 원게 이에 하는 그는 그의 그호을 생였던 일이 그는 선비…는 이하는 그는 그는 들는 하고 그의 그
#
# Epoch: 38/50 471/471 Error: 30.529029680216464
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇의 순고 그는 자도 그리고 고 그의 그리고 그는 어라는 그의 돌아니.
# 이는 그는 돌리고 나이는 그리고 나들고 그의 그의 그의 그리고 하고 그의 그는 아침이고 그는 가는 고 가고 아서방고 이서 안고 그는 그의 어머니는 이히이는 같이서 방를 다가 한오고 이서 그는 가지고 이의 이는 그의 뭐리고 그는 가고 옥점이는 그는 어머니는 그는 부이는 그리는 그의 이도 그
#
# Epoch: 39/50 471/471 Error: 25.86640456663083
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하고 보았다. 그리고 바라보니 일어 그리고 것이 부시고 미어 어머니니 그래고 그 사하고 내 어머니는 어머니는 그리고 물어 있라보이 오어 수어 나 그래 있었다. 그리고 것하였다. 그리고 그의 어머니는 내하고 사라보았다. 그리고 것고 일어 못 되었다. 그리고 일어나 그리고 그리고 일어 것이 하고 보이 그의 어머니의 저려 안 그리고 하고 것이 내 오아 새 하
#
# Epoch: 40/50 471/471 Error: 26.68941510713268
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇는 간이 안 나리고 무이는 뒤을 이렇게 바라보이 이서 그는 등이 한 모양이 그리가 이렇이 사리고 모이 하고 나무서 선비는 보았다.
# 이 보았다.
# 그째는 옥점이는 가인이 맘이 가지는 사리고 오는 손시는 돌리를 사점이는 밥이 어머니는 보며 그리고 한 이렇게 수수이 쳐리고 속이 집이 없이 좀 하았다.
# 이리는 이렇게 이만 이서 선비는 것이 것이 부양이 눈이 들이
#
# Epoch: 41/50 471/471 Error: 28.65442082809206
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 그의 의 것을 하였다.
# 그가 그는 것을 그의 것을 한, 보았다.
# 그래서 눈을 말이다. 그는 것을 그리를 그의 것을 말을 옷으로 놓지 못다.
# 그의 안을 더라보았다. 그리에 소리의 소리고 가라보았다. 그리에 눈을 다.
# 선비는 그의 것이다. 그리는 것을 보았다.
# 그는 것을 그의 눈을 이다. 그래서 돌을 그리에 얼양이다.
# 그의 눈을 말을 것이다. 그리고 그의
#
# Epoch: 42/50 471/471 Error: 27.280800250152897
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 이는 것이가?
# 그의 의의이를 말을 이놈이를 들었다.
# 이놈이는 손을 하여다.
# 그는 어머니의 옥점이는 소리를 바라보았다.
# 어머니는 옥점이는 아무의이의이는 눈을 하였다.
# 이렇게 말이다.
# 이는 이런 이렇게 들을 하고 이야지를 소리를 어머니는 이렇게 하여지나,
# 어머니는 소리를 들어가?
# 이렇게 웬을 하였다.
# 옥점이는 어머니는 어머니는 것이가?
# 이것이다.
# 이는 소리
#
# Epoch: 43/50 471/471 Error: 25.777040057161116
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 이 이었다. 그리고 이 가 하여 같이 하여 하고 가 하였다. 그리고 무슨 이 이 이 같이 하고 있었다.
# 그는 아버지 이 들어 가서 놓고 가라 하니 가각하고 이런 하고 같이 가시 하였다.
# 그리고 이 있으나 들려 하였다.
# 그들이 무슨 선비 이 들어 하고 밤하여 하고 일이 하였다. 그리고 이렇게 하였다. 그리고 일어 없는 것을 하였다. 그리고 이 하고
#
# Epoch: 44/50 471/471 Error: 26.004983663795993
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 이 그들은 것 않지 말을 때 오는 것이 새 하고 그째 일을 하였다.
# 그 무슨 신철이 이 새어 아 때 이 싫으로 들어 나 말 들여 놓고 방은 생각이 하고 보다 하고 불 부아 웬 보고 이렇게 자지 말을 보았다. 그의 눈에 일 손을 하면 이 또 하였다. 그리 이 섰다. 옥점 어머니 어머니 말 들어 들고 있었다. 옥점 가 이 한 또 한 후 자 수 해 번 아어
#
# Epoch: 45/50 471/471 Error: 25.239328949577093
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 하였다.
# 선비 어머니는 나서 나무?
# 시르한 보지가 말이나 따라 바라보니 가서 못하는 안 한 따라 있다. 그는 것은 와서 한 동하나 나는 어머니는 아무물은 일어 왔다. 그는 말을 보았다.
# 선비 소리를 한 일어왔다. 그리고 일어나 바라보며 마시 한 일어나왔다. 그러나 일어나 놓고 그리고 일어나 나왔다. 그리고 선비가 나왔다.
# 어머니는 줄 나려 나 들어가 하
#
# Epoch: 46/50 471/471 Error: 26.282780102719094
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇게 같아 그래 그리고 옥점이는 그래서 이렇게 그리고 그의 계래서 그리고 그리고 그리를 바라서 그리고 그리고 그리고 그러 그리고 그리고 머리를 맞어 어머니.
# 어머니 그리에 이렇게 일어 어머니는 그리가 그리고 기어 오양이 그리고 그리고 그리고 머리를 그리고 어머니 그리고 그리고 문 옥점이는 그리고 그래에 그리를 다시 내 그리고 그리를 사다. 그리고 그리고 옥점
#
# Epoch: 47/50 471/471 Error: 58.807710643149875
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇지지지지지지라지를지지지인지며지지지지.
# 아지지.
# 그는지에지지머니지.
# 지지지.
#
# 지머니지,
# 그는지며.
# 어머니.
# 그는지지지를지지지기지를을지지지지지지며지을을지지지을에는지지지지지라며지지머니지는지을지.
# 지는지지가는
# 그리고,지며
# 지들
# 지,
# 그는
#
# 그리고지는
# 어머니.
# 그는지지.
# 어지지지지지하며
# 어머니지을지를지지지점를지지
# 아지기지지지지지지서를지며지지지지지지지지지을지지을지지
#
# Epoch: 48/50 471/471 Error: 47.75059083349508
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇으니다.
# 이다.
# 이다.
# 이는.
# 이놈.
# 이다.
# 이는
# 이나.
# 이는
# 아이다.
# 이나.
# 이다.
# 이다.
# 이는
# 듯이는
# 이는
# 이는
# 이다.
# 이려.
# 이다.
# 이는
# 이다.
# 이다.
# 이다.
# 이는
# 이는
# 이지.
# 이는
# 이다.
# 이다.
# 이니.
# 이다.
# 이는
# 이라.
# 이는
# 이는
# 이는
# 이구는
# 이는
# 이라.
# 이다.
# 이는
# 이지도
# 이다.
# 이들다.
# 이는
# 이는지.
# 아니를…….
# 이는
# 이는
# 이다.
# 이는
# 이다.
#
#
# Epoch: 49/50 471/471 Error: 34.75276473750426
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇은 그리고 있에 그래 그리가 그리고 지 그리고 민에 있게 글에 그리고 먹지 바라고 신에 양들도 그리고 그리고 그리고 일리고 사머니 있식 있고 어 그리고 그리고 그리고 그리며 말을 인지 그리고 그 ! 그리고 그리고 그리고 그 어서 선비 싶았다. 그리에 뭐 그리고 말에 그리고 먹고 그리고 그리고 그리고 미지 그리고 그리고 일일지 그리 그 일일람 탁라 그리고 그
#
# Epoch: 50/50 471/471 Error: 31.50116312238527
# Seed: 이 산등에 올라서면 용연 동네는 저렇
# 이 산등에 올라서면 용연 동네는 저렇다.
# 그는 그는 그는 그는 하고 그리는 그가 하다.
#
# 그는 그는 선거 음가 그는 그는 보을 그는 가로 어지.
# 그래
# 에가 무어지 그는 버아이 그는 나도 그리.
#
# .
# 이 선며 비는 어하다.
# 그는 그가 거어, 가가 끝가가 아이 그는 어며 가보다.
#
# 그며 그보이 그는 생고 그는 들에 그는 그는 뒤이 한가 말이 서 그는 그의 아라는 그는 가가 것이 그는 그는 가지
